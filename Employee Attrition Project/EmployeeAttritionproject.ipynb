# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import squarify

# %%
df= pd.read_csv('Employee_Attrition.csv')

# %%
df.head(10)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
# 5   32        No  Travel_Frequently       1005  Research & Development
# 6   59        No      Travel_Rarely       1324  Research & Development
# 7   30        No      Travel_Rarely       1358  Research & Development
# 8   38        No  Travel_Frequently        216  Research & Development
# 9   36        No      Travel_Rarely       1299  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# ...

# %%
df.shape
# Out:
# (1470, 35)

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
print(f'Number of Duplicates :{df.duplicated().sum()}')
# Out:
# Number of Duplicates :0

# %%
# Count of Employees
CountofEmployees= df['EmployeeCount'].sum()
print(CountofEmployees)
# Out:
# 1470

# %%
# Attrition Count
#df['Attrition'].value_counts()['Yes']
Attrition_count=((df['Attrition']== 'Yes').sum())
print(Attrition_count)
# Out:
# 237

# %%
# Attrition Rate
Total_attr= df['Attrition'].count()
Percentage_attr = (Attrition_count/Total_attr)*100
print(f"{round(Percentage_attr,2)}%")
# Out:
# 16.12%

# %%
#Average Age
avg_age = df['Age'].mean()
print(round(avg_age,0))
# Out:
# 37.0

# %%
#Average Salary Hike
AvgSalaryHikePerc=  df['PercentSalaryHike'].mean()
print(round(AvgSalaryHikePerc,0))
# Out:
# 15.0

# %%
#Average Years
Avg_yrs= df['YearsAtCompany'].mean()
print(round(Avg_yrs,0))
# Out:
# 7.0

# %%
#Avg monthly income
Avg_month_inc= df['MonthlyIncome'].mean()
print(round(Avg_month_inc,0))
# Out:
# 6503.0

# %%
#Gender Count
AttrbyGender= df[df['Attrition']=='Yes'].groupby('Gender').size()
print(AttrbyGender)
# Out:
# Gender
# Female     87
# Male      150
# dtype: int64

# %%
#Dept Count
AttrbyDept=  df[df['Attrition']=='Yes'].groupby('Department').size()
print(AttrbyDept)
# Out:
# Department
# Human Resources            12
# Research & Development    133
# Sales                      92
# dtype: int64

# %%
#Attrition By JobRole
AttrByJobrole= df[df['Attrition']=='Yes'].groupby('JobRole').size()
print(AttrByJobrole)
# Out:
# JobRole
# Healthcare Representative     9
# Human Resources              12
# Laboratory Technician        62
# Manager                       5
# Manufacturing Director       10
# Research Director             2
# Research Scientist           47
# Sales Executive              57
# Sales Representative         33
# dtype: int64

# %%
# Attrition By Age
AttrbyAge= df[df['Attrition']=='Yes'].groupby('Age').size()
print(AttrbyAge)
# Out:
# Age
# 18     4
# 19     6
# 20     6
# 21     6
# 22     5
# 23     4
# 24     7
# 25     6
# 26    12
# 27     3
# 28    14
# 29    18
# 30     9
# 31    18
# 32    11
# 33    12
# 34     9
# 35    10
# 36     6
# 37     6
# 38     2
# 39     6
# 40     5
# 41     6
# 42     2
# 43     2
# 44     6
# 45     2
# 46     4
# 47     3
# 48     2
# 49     2
# 50     5
# 51     2
# 52     3
# 53     2
# 55     3
# 56     3
# 58     5
# dtype: int64

# %%
Jobinv_attr=  df[df['Attrition']=='Yes'].groupby('JobInvolvement').size()
print(Jobinv_attr)
# Out:
# JobInvolvement
# 1     28
# 2     71
# 3    125
# 4     13
# dtype: int64

# %%
Jobinv_attrition= df.groupby(['JobInvolvement','Attrition']).size().unstack()
print(Jobinv_attrition)
# Out:
# Attrition        No  Yes
# JobInvolvement
# 1                55   28
# 2               304   71
# 3               743  125
# 4               131   13

# %%
AttrbyTrvl=  df[df['Attrition']=='Yes'].groupby('BusinessTravel').size()
print(AttrbyTrvl)
# Out:
# BusinessTravel
# Non-Travel            12
# Travel_Frequently     69
# Travel_Rarely        156
# dtype: int64

# %%
BusiTrvl_attr= df.groupby(['BusinessTravel','Attrition']).size().unstack()
print(BusiTrvl_attr)
# Out:
# Attrition           No  Yes
# BusinessTravel
# Non-Travel         138   12
# Travel_Frequently  208   69
# Travel_Rarely      887  156

# %%
AttrbySalHikeper =  df[df['Attrition']=='Yes'].groupby('PercentSalaryHike').size()
print(AttrbySalHikeper)
# Out:
# PercentSalaryHike
# 11    41
# 12    33
# 13    34
# 14    24
# 15    18
# 16    14
# 17    14
# 18    13
# 19     9
# 20     7
# 21     5
# 22    12
# 23     6
# 24     6
# 25     1
# dtype: int64

# %%
AttrbyYrsAtComp =  df[df['Attrition']=='Yes'].groupby('YearsAtCompany').size()
print(AttrbyYrsAtComp.head(10) )
# Out:
# YearsAtCompany
# 0    16
# 1    59
# 2    27
# 3    20
# 4    19
# 5    21
# 6     9
# 7    11
# 8     9
# 9     8
# dtype: int64

# %%
AttrbyWLB= df[df['Attrition']=='Yes'].groupby('WorkLifeBalance').size()
print(AttrbyWLB)
# Out:
# WorkLifeBalance
# 1     25
# 2     58
# 3    127
# 4     27
# dtype: int64

# %%
Worklife_attr= df.groupby(['WorkLifeBalance','Attrition']).size().unstack()
print(Worklife_attr)
# Out:
# Attrition         No  Yes
# WorkLifeBalance
# 1                 55   25
# 2                286   58
# 3                766  127
# 4                126   27

# %%
PerfRtng_attr= df[df['Attrition']=='Yes'].groupby('PerformanceRating').size()
print(PerfRtng_attr)
# Out:
# PerformanceRating
# 3    200
# 4     37
# dtype: int64

# %%
PerfRtng_attrition= df.groupby(['PerformanceRating','Attrition']).size().unstack()
print(PerfRtng_attrition)
# Out:
# Attrition            No  Yes
# PerformanceRating
# 3                  1044  200
# 4                   189   37

# %%
Jobsat_attr= df.groupby(['JobSatisfaction','Attrition']).size().unstack()
print(Jobsat_attr)
# Out:
# Attrition         No  Yes
# JobSatisfaction
# 1                223   66
# 2                234   46
# 3                369   73
# 4                407   52

# %%
AttrbyJobSatisfaction =  df[df['Attrition']=='Yes'].groupby('JobSatisfaction').size()
print(AttrbyJobSatisfaction)
# Out:
# JobSatisfaction
# 1    66
# 2    46
# 3    73
# 4    52
# dtype: int64

# %%
Ovrtime_attr= df.groupby(['OverTime','Attrition']).size().unstack()
print(Ovrtime_attr)
# Out:
# Attrition   No  Yes
# OverTime
# No         944  110
# Yes        289  127

# %%
Overtime_attr =  df[df['Attrition']=='Yes'].groupby('JobSatisfaction').size()
print(Overtime_attr)
# Out:
# JobSatisfaction
# 1    66
# 2    46
# 3    73
# 4    52
# dtype: int64

# %%
AttrbyEdu= df[df['Attrition'] == 'Yes'].groupby('EducationField').size()
print(AttrbyEdu)
# Out:
# EducationField
# Human Resources      7
# Life Sciences       89
# Marketing           35
# Medical             63
# Other               11
# Technical Degree    32
# dtype: int64

# %%
# Attrition Distribution
attrition = df['Attrition'].value_counts(normalize=True)
plt.figure(figsize=(6,5))
ax = sns.barplot(x=attrition.index, y=attrition, palette = 'deep', hue= attrition, legend=False)
for p in ax.patches:
    ax.annotate(f'{p.get_height() * 100:.2f}%',
                (p.get_x() + p.get_width() / 2.,
p.get_height()),
                ha='center', va='bottom')
plt.title('Distribution of Attrition Rate')
plt.xlabel('Attrition')
plt.ylabel('Percentage')
plt.tight_layout()
plt.show()

# %%
# Visualizations :-
# Attrition by Education (
plt.figure(figsize=(9,5))
AttrbyEdu.plot(kind= 'pie', autopct= '%1.1f%%', startangle= 90)
centre_circle = plt.Circle((0,0) , 0.7, color = 'white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
plt.title('Attrition by Education')
plt.show()

# %%
#  Attrition by Gender (TreeMap)
plt.figure(figsize=(5,5))
labels= [f"{label}\n{value}" for label,
         value in zip(AttrbyGender.index,AttrbyGender.values)]
squarify.plot(sizes = AttrbyGender.values,label = labels ,alpha= 0.8)
plt.axis('off')
plt.title('Attrition by Gender')
plt.show()

# %%
# Attrition by Age
plt.figure(figsize=(6,5))
sns.histplot( data = df[df['Attrition']=='Yes'], x='Age', kde= True)
plt.title('Attrition Distribution by Age')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
# Attrition by JobRole
plt.figure(figsize=(6,5))
sns.countplot( data = df[df['Attrition']=='Yes'], y='JobRole', hue='JobRole')
plt.title('Attrition Distribution by JobRole')
plt.xlabel('Count')
plt.ylabel('JobRole')
plt.show()

# %%
# Attrition by Department and Salary Hike Percent
plt.figure(figsize=(15,6))
ax1= plt.subplot(1, 2, 1)
sns.countplot(data = df[df['Attrition']=='Yes'], x= 'Department', ax=ax1, hue= 'Department')
ax1.set_title('Attrition by Department')
ax1.set_xlabel('Department')
ax1.set_ylabel('Count')
ax2= plt.subplot(1, 2, 2)
sns.histplot( data = df[df['Attrition']=='Yes'], x='PercentSalaryHike', kde= True)
ax2.set_title('Attrition Distribution by Salary Hike %')
ax2.set_xlabel('Salary Hike %')
ax2.set_ylabel('Count')
plt.tight_layout()
plt.show()

# %%
# Attrition by Business Travel
fig, (ax1, ax2)= plt.subplots(1,2, figsize=(15,6))
BusiTrvl_attr.plot(kind='bar', ax= ax1)
ax1.set_title('Business Travel Count by Attrition')
ax1.set_xlabel('Attrition')
ax1.set_ylabel('Count')

sns.countplot(data = df[df['Attrition']=='Yes'], x= 'BusinessTravel', ax=ax2, hue= 'BusinessTravel')
ax2.set_title('Attrition by Business Travel')
ax2.set_xlabel('Travelling Frequency')
ax2.set_ylabel('Count')
plt.tight_layout()
plt.show()

# %%
# Attrition by Job Satisfaction
fig, (ax1, ax2)= plt.subplots(1,2, figsize=(15,6))
Worklife_attr.plot(kind='bar', ax= ax1)
ax1.set_title('Attrition')
ax1.set_xlabel('Job Satisfaction')
ax1.set_ylabel('Count')
sns.countplot( data = df[df['Attrition']=='Yes'], x= 'JobSatisfaction', ax= ax2, hue='JobSatisfaction', palette='deep',legend=False)
ax2.set_title('Attrition by Job Satisfaction')
ax2.set_xlabel('Job Satisfaction')
ax2.set_ylabel('Count')
plt.tight_layout()
plt.show()

# %%
# Attrition by Job Involvement
fig, (ax1, ax2)= plt.subplots(1,2, figsize=(15,6))
Jobinv_attrition.plot(kind='bar', ax= ax1)
ax1.set_title('Attrition Count')
ax1.set_xlabel('Job Involvement')
ax1.set_ylabel('Count')

sns.countplot( data = df[df['Attrition']=='Yes'], x='JobInvolvement', ax= ax2, hue='JobInvolvement', palette='deep',legend=False)
ax2.set_title('Attrition by Job Involvement')
ax2.set_xlabel('Job Involvemnet')
ax2.set_ylabel('Count')
plt.tight_layout()
plt.show()

# %%
#Attrition by Work Life Balance

fig, (ax1, ax2)= plt.subplots(1,2, figsize=(15,6))
Worklife_attr.plot(kind='bar', ax= ax1)
ax1.set_title('Attrition Count')
ax1.set_xlabel('Work Life Balance')
ax1.set_ylabel('Count')

sns.countplot( data = df[df['Attrition']=='Yes'], x='WorkLifeBalance', ax= ax2, hue='WorkLifeBalance', palette='deep',legend=False)
ax2.set_title('Attrition by Work Life Balance')
ax2.set_xlabel('Worklife Balance')
ax2.set_ylabel('Count')
plt.tight_layout()
plt.show()

# %%
# Attrition by Performance Ratings "
fig, (ax1, ax2)= plt.subplots(1,2, figsize=(15,6))
PerfRtng_attrition.plot(kind='bar', ax= ax1)
ax1.set_title('Attrition')
ax1.set_xlabel('Performance Rating')
ax1.set_ylabel('Count')

sns.countplot( data = df[df['Attrition']=='Yes'], x='PerformanceRating', ax= ax2, hue='PerformanceRating', palette='deep',legend=False)
ax2.set_title('Attrition by Performance Rating')
ax2.set_xlabel('Performance Rating')
ax2.set_ylabel('Count')
plt.tight_layout()
plt.show()

# %%
# Attrition by Overtime "
fig, (ax1, ax2)= plt.subplots(1,2, figsize=(15,6))
Ovrtime_attr.plot(kind='bar', ax= ax1)
ax1.set_title('Attrition')
ax1.set_xlabel('Overtime')
ax1.set_ylabel('Count')

sns.countplot( data = df[df['Attrition']=='Yes'], x='OverTime', ax= ax2, hue='OverTime', palette='deep',legend=False)
ax2.set_title('Attrition by Overtime')
ax2.set_xlabel('Overtime')
ax2.set_ylabel('Count')
plt.tight_layout()
plt.show()

# %%
# Attrition by Years At Company
sns.kdeplot(data = df[df['Attrition']=='Yes'], x='YearsAtCompany', fill=True)
plt.title('Attrition by Years At Company')
plt.xlabel('Years')
plt.ylabel('Density')
plt.show()

# %%
# Attrition by Monthly income
plt.figure(figsize=(10,5))
sns.boxplot( data = df, x= 'Attrition', y= 'MonthlyIncome', hue = 'Attrition')
plt.title('Attrition By Monthly Income')
plt.ylabel('Monthly Income')
plt.xlabel('Attrition')
plt.show()
